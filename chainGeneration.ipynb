# %% [markdown]
# # Markov Chain Generation
# In this notebook, we generate the necessary Markov Chains for each author which will be used as likelihood functions during the identification process.

# %%
import string
import sys
import re

class MarkovChain():
    """
    Markov Chain class. 
    chain:       nested dictionary representing the number of occurences of a word given the previous word.
    wordCount:   dictionary of the number of total number of words (value) that have occured after the previous word (key).
    """
    chain = {}
    wordCount = 0
    
    def addWord(self, prevWord, word):
        """
        Add a word to the Markov Chain.
        Takes the previous word and the current word as strings
        """
        self.chain[(prevWord, word)] = self.chain.get((prevWord, word), 0) + 1
        self.wordCount += 1
        
#         # If the word isn't in the prefix's dictionary, add it
#         if not self.chain[prevWord].get(word):
#             self.chain[prevWord][word] = 0
            
#         if not self.chain.wordCount[prevWord]:
#             self.wordCount[prevWord] = 0
                
#         self.chain[prevWord][word] += 1
#         self.wordCount[prevWord] += 1
        
#         if not self.chain.get(prevWord): # If the word doesn't already exist, add one to the total number of words
#             self.wordCount[prevWord] = 1
#             self.wordCount[prevWord] += 1
#         self.chain[prevWord][word] += 1
        
    def addSentence(self, sentence):
        """
        Process a "sentence" to produce a Markov Chain. Takes a sentence as a list of lowercase words.
        NO ASTERISKS. SERIOUSLY.
        """
        # '*' represents the beginning of a sentence in the chain. 
        # This way, we can determine the probability of a word starting a sentence
        modifiedSentence = ['*'] + sentence
        
        if len(sentence) > 1:
            for i in [i + 1 for i in range(len(sentence))]: # Start at the second word
                self.addWord(sentence[i-1], sentence[1])
        
    def getProb(self, prevWord, word):
        """
        Return the probability of getting word given prevWord.
        Takes two strings.
        """
        return self.chain[(prevWord, word)]/self.wordCount
    
def processGutenberg(fileName):
    """
    Process a Gutenberg text file.
    fileName: string
    returns a markovChain object.
    """
    f = open(fileName)
    
    #Skip to the beginning of the actual text
    for line in f:
        if line.startswith("*** START OF THIS PROJECT"):
            break
    
    text = ''
    markovChain = MarkovChain()
    
    # Put the text into one big string
    for line in f:
        # Stop when hitting the end of the book
        if line.startswith("*** END OF THIS PROJECT"):
            break
        
        text += line + ' '
        
    sentences = re.split('[.?!]', text) # Seperate text into a list of sentences sentence
    
    for sentence in sentences:
        # Make all words lowercase and strip off punctuation
        sentenceList = ''.join(char for char in sentence if char in set(string.letters + string.digits + ' ')).lower().split()
        
        # Process the sentence in the Markov Chain
        markovChain.addSentence(sentenceList)
    
    f.close()
    
    return markovChain

# %%
greatExp = processGutenberg('GreatExpectations.txt')

# %%
greatExp.chain
# Out:
# {('instantly', 'miss'): 1,
#  ('would', 'stood'): 1,
#  ('gate', 'heard'): 1,
#  ('twist', 'i'): 2,
#  ('it', 'couldnt'): 1,
#  ('mrs', 'lady'): 1,
#  ('halfyearly', 'it'): 1,
#  ('hart', 'i'): 1,
#  ('about', 'hung'): 1,
#  ('hunter', 'i'): 1,
#  ('have', 'made'): 3,
#  ('gifthorses', 'handel'): 1,
#  ('it', 'younger'): 1,
#  ('write', 'rather'): 1,
#  ('think', 'are'): 1,
#  ('about', 'then'): 2,
#  ('circumstances', 'mean'): 1,
#  ('for', 'made'): 4,
#  ('gird', 'was'): 1,
#  ('didnt', 'two'): 1,
#  ('done', 'say'): 1,
#  ('knew', 'had'): 7,
#  ('my', 'construction'): 3,
#  ('house', 'heavily'): 1,
#  ('equally', 'xxviii'): 1,
#  ('going', 'as'): 3,
#  ('moaned', 'miss'): 3,
#  ('cork', 'a'): 1,
#  ('sounds', 'statement'): 1,
#  ('with', 'gargery'): 2,
#  ('ran', 'imperceptible'): 1,
#  ('money', 'since'): 1,
#  ('half', 'then'): 1,
#  ('to', 'accidentally'): 1,
#  ('in', 'up'): 2,
#  ('opinion', 'hesitated'): 1,
#  ('bacon', 'we'): 1,
#  ('nor', 'giv'): 1,
#  ('exacted', 'he'): 1,
#  ('put', 'her'): 1,
#  ('fortunes', 'my'): 1,
#  ('made', 'boast'): 2,
#  ('making', 'little'): 1,
#  ('writing', 'should'): 1,
#  ('stars', 'let'): 1,
#  ('establishment', 'xxvi'): 1,
#  ('into', 'came'): 4,
#  ('pumblechook', 'who'): 2,
#  ('at', 'dropped'): 1,
#  ('theres', 'see'): 1,
#  ('didnt', 'looked'): 1,
#  ('houses', 'is'): 1,
#  ('purchases', 'occurred'): 1,
#  ('until', 'through'): 1,
#  ('house', 'have'): 2,
#  ('was', 'avenging'): 2,
#  ('mild', 'person'): 1,
#  ('an', 'pretended'): 1,
#  ('folded', 'appeared'): 1,
#  ('crying', 'verily'): 1,
#  ('havisham', 'heerd'): 1,
#  ('boy', 'look'): 1,
#  ('greatly', 'on'): 1,
#  ('away', 'occurred'): 1,
#  ('there', 'saw'): 7,
#  ('same', 'it'): 1,
#  ('believe', 'havisham'): 1,
#  ('did', 'laid'): 1,
#  ('neither', 'thing'): 1,
#  ('privately', 'married'): 1,
#  ('the', 'lvii'): 3,
#  ('motherly', 'in'): 1,
#  ('baize', 'this'): 1,
#  ('our', 'became'): 1,
#  ('coach', 'had'): 2,
#  ('iron', 'believed'): 2,
#  ('if', 'room'): 1,
#  ('disquiet', 'cannot'): 1,
#  ('clock', 'was'): 4,
#  ('go', 'all'): 3,
#  ('no', 'miss'): 2,
#  ('malignant', 'was'): 1,
#  ('i', 'pausing'): 3,
#  ('pattern', 'two'): 1,
#  ('of', 'barley'): 3,
#  ('simple', 'pleasant'): 1,
#  ('set', 'he'): 1,
#  ('suddenly', 'day'): 1,
#  ('if', 'mental'): 1,
#  ('believe', 'asked'): 1,
#  ('as', 'swinging'): 1,
#  ('uneasy', 'xii'): 1,
#  ('romantic', 'though'): 1,
#  ('in', 'can'): 2,
#  ('great', 'had'): 6,
#  ('dont', 'then'): 1,
#  ('pens', 'sound'): 1,
#  ('whatever', 'never'): 1,
#  ('and', 'passed'): 2,
#  ('coiner', 'shook'): 1,
#  ('turnkey', 'the'): 2,
#  ('apiece', 'he'): 1,
#  ('note', 'gave'): 1,
#  ('all', 'threw'): 1,
#  ('office', 'he'): 3,
#  ('life', 'miserable'): 1,
#  ('state', 'state'): 3,
#  ('out', 'course'): 1,
#  ('wearers', 'every'): 1,
#  ('hot', 'there'): 1,
#  ('as', 'writes'): 1,
#  ('her', 'last'): 3,
#  ('quite', 'laughed'): 1,
#  ('took', 'collation'): 1,
#  ('many', 'havisham'): 1,
#  ('boyannounced', 'he'): 1,
#  ('was', 'house'): 5,
#  ('feeling', 'offered'): 1,
#  ('ready', 'he'): 1,
#  ('especially', 'said'): 1,
#  ('returned', 'dont'): 4,
#  ('his', 'old'): 4,
#  ('way', 'held'): 1,
#  ('to', 'came'): 21,
#  ('out', 'broke'): 1,
#  ('chest', 'closet'): 1,
#  ('usual', 'joe'): 1,
#  ('trabb', 'or'): 1,
#  ('place', 'chair'): 1,
#  ('notion', 'shook'): 1,
#  ('occurred', 'got'): 1,
#  ('we', 'biddy'): 2,
#  ('floor', 'with'): 1,
#  ('out', 'which'): 3,
#  ('furious', 'furious'): 1,
#  ('the', 'kept'): 2,
#  ('off', 'pip'): 1,
#  ('alone', 'they'): 1,
#  ('deliberation', 'course'): 1,
#  ('villain', 'you'): 1,
#  ('full', 'dont'): 1,
#  ('at', 'questioning'): 1,
#  ('carrying', 'or'): 1,
#  ('best', 'i'): 4,
#  ('shoulder', 'shall'): 1,
#  ('was', 'true'): 1,
#  ('at', 'arranged'): 1,
#  ('would', 'monday'): 4,
#  ('that', 'looking'): 1,
#  ('to', 'folded'): 2,
#  ('pursued', 'returning'): 1,
#  ('are', 'sentiments'): 1,
#  ('across', 'appeared'): 1,
#  ('speech', 'at'): 1,
#  ('while', 'went'): 3,
#  ('gentlemen', 'a'): 1,
#  ('used', 'fell'): 1,
#  ('enough', 'finished'): 1,
#  ('costs', 'in'): 1,
#  ('hurt', 'dont'): 3,
#  ('give', 'rather'): 1,
#  ('it', 'unfolding'): 1,
#  ('was', 'really'): 5,
#  ('sandy', 'said'): 1,
#  ('yah', 'i'): 1,
#  ('theyre', 'eat'): 1,
#  ('were', 'mentioning'): 1,
#  ('elses', 'had'): 2,
#  ('artful', 'pocket'): 1,
#  ('head', 'no'): 1,
#  ('dead', 'with'): 1,
#  ('case', 'a'): 1,
#  ('inkstand', 'chap'): 1,
#  ('requiring', 'it'): 1,
#  ('last', 'yielded'): 1,
#  ('be', 'has'): 2,
#  ('another', 'questioning'): 1,
#  ('round', 'aint'): 1,
#  ('close', 'havisham'): 1,
#  ('letter', 'i'): 3,
#  ('answer', 'am'): 1,
#  ('if', 'joe'): 3,
#  ('sortalluding', 'bearing'): 1,
#  ('kind', 'you'): 1,
#  ('hush', 'there'): 1,
#  ('that', 'and'): 18,
#  ('style', 'was'): 1,
#  ('gentleman', 'me'): 1,
#  ('passed', 'receiving'): 1,
#  ('promised', 'as'): 1,
#  ('would', 'threw'): 2,
#  ('and', 'royal'): 2,
#  ('no', 'brought'): 1,
#  ('old', 'dear'): 7,
#  ('impart', 'prefer'): 1,
#  ('corner', 'i'): 7,
#  ('such', 'made'): 1,
#  ('both', 'sir'): 1,
#  ('buryingground', 'entered'): 1,
#  ('saw', 'epergne'): 1,
#  ('improves', 'you'): 1,
#  ('dark', 'windows'): 1,
#  ('beckoned', 'governor'): 1,
#  ('somebody', 'came'): 1,
#  ('clean', 'lay'): 1,
#  ('his', 'calling'): 1,
#  ('man', 'that'): 5,
#  ('could', 'pushed'): 1,
#  ('compeyson', 'doubted'): 1,
#  ('traces', 'were'): 1,
#  ('just', 'came'): 1,
#  ('brought', 'they'): 1,
#  ('fire', 'xliv'): 1,
#  ('a', 'heavilythat'): 2,
#  ('was', 'dear'): 3,
#  ('being', 'consigned'): 1,
#  ('fallen', 'never'): 1,
#  ('the', 'bread'): 2,
#  ('my', 'coffeeroom'): 1,
#  ('thinking', 'she'): 1,
#  ('floursack', 'he'): 1,
#  ('if', 'greataunt'): 1,
#  ('here', 'night'): 1,
#  ('on', 'bearing'): 1,
#  ('gardener', 'am'): 1,
#  ('such', 'hed'): 1,
#  ('bottom', 'at'): 1,
#  ('read', 'constables'): 1,
#  ('away', 'father'): 1,
#  ('philip', 'dont'): 1,
#  ('successfully', 'she'): 1,
#  ('dark', 'such'): 1,
#  ('pieces', 'an'): 1,
#  ('country', 'father'): 1,
#  ('do', 'not'): 3,
#  ('was', 'boat'): 1,
#  ('performances', 'all'): 1,
#  ('powerful', 'the'): 1,
#  ('remarkable', 'xvii'): 1,
#  ('a', 'brewing'): 1,
#  ('herbert', 'these'): 1,
#  ('and', 'things'): 2,
#  ('six', 'as'): 1,
#  ('the', 'sister'): 22,
#  ('wild', 'of'): 1,
#  ('comforted', 'he'): 1,
#  ('pocketbook', 'the'): 1,
#  ('young', 'short'): 1,
#  ('wilderness', 'a'): 1,
#  ('avenging', 'avenging'): 1,
#  ('girl', 'seemed'): 1,
#  ('much', 'smiled'): 1,
#  ('object', 'as'): 1,
#  ('joe', 'length'): 1,
#  ('visit', 'she'): 1,
#  ('napkin', 'that'): 1,
#  ('cloak', 'in'): 2,
#  ('go', 'only'): 2,
#  ('fine', 'prominent'): 1,
#  ('and', 'state'): 2,
#  ('difficulty', 'had'): 1,
#  ('bed', 'so'): 1,
#  ('since', 'having'): 1,
#  ('mr', 'judicious'): 1,
#  ('besides', 'judged'): 1,
#  ('so', 'statement'): 1,
#  ('but', 'relieve'): 1,
#  ('future', 'more'): 1,
#  ('very', 'influence'): 1,
#  ('sharpest', 'verily'): 1,
#  ('nodded', 'paused'): 1,
#  ('ancient', 'suppose'): 1,
#  ('clem', 'that'): 1,
#  ('wardenouncing', 'as'): 1,
#  ('in', 'havishams'): 1,
#  ('herself', 'giv'): 1,
#  ('fees', 'one'): 1,
#  ('even', 'those'): 1,
#  ('with', 'further'): 1,
#  ('before', 'walked'): 1,
#  ('dry', 'sarah'): 1,
#  ('confessed', 'i'): 2,
#  ('particular', 'have'): 1,
#  ('wheelwrights', 'were'): 1,
#  ('by', 'joe'): 3,
#  ('she', 'wrote'): 2,
#  ('abroad', 'when'): 1,
#  ('oncommon', 'it'): 1,
#  ('money', 'to'): 2,
#  ('step', 'advancing'): 1,
#  ('made', 'defended'): 1,
#  ('they', 'such'): 1,
#  ('part', 'my'): 1,
#  ('directions', 'wits'): 1,
#  ('couldnt', 'me'): 1,
#  ('knew', 'what'): 1,
#  ('back', 'bitter'): 1,
#  ('lofty', 'in'): 1,
#  ('to', 'appointed'): 2,
#  ('word', 'really'): 1,
#  ('himself', 'soldier'): 1,
#  ('stomach', 'a'): 2,
#  ('if', 'after'): 3,
#  ('a', 'guardian'): 2,
#  ('another', 'when'): 1,
#  ('it', 'looked'): 6,
#  ('fortunate', 'is'): 1,
#  ('book', 'aint'): 1,
#  ('i', 'cleared'): 1,
#  ('ghost', 'i'): 4,
#  ('myself', 'earnestly'): 2,
#  ('breathe', 'seem'): 1,
#  ('countenance', 'watched'): 1,
#  ('seems', 'am'): 1,
#  ('as', 'showed'): 4,
#  ('breaths', 'had'): 1,
#  ('there', 'do'): 3,
#  ('ever', 'couldnt'): 1,
#  ('on', 'felt'): 2,
#  ('volume', 'soon'): 1,
#  ('agein', 'xxxvi'): 1,
#  ('for', 'fixing'): 1,
#  ('pulled', 'last'): 1,
#  ('bashful', 'but'): 1,
#  ('slumbering', 'was'): 1,
#  ('safe', 'all'): 3,
#  ('the', 'great'): 4,
#  ('collectedly', 'was'): 1,
#  ('inthe', 'last'): 1,
#  ('help', 'are'): 1,
#  ('and', 'sun'): 5,
#  ('effect', 'gave'): 1,
#  ('be', 'must'): 7,
#  ('if', 'youre'): 2,
#  ('kept', 'always'): 1,
#  ('looked', 'they'): 4,
#  ('until', 'you'): 4,
#  ('that', 'occasion'): 1,
#  ('saw', 'childish'): 1,
#  ('halfway', 'made'): 1,
#  ('made', 'xxxv'): 1,
#  ('them', 'there'): 3,
#  ('i', 'into'): 1,
#  ('of', 'called'): 4,
#  ('saying', 'i'): 7,
#  ('discussion', 'now'): 1,
#  ('not', 'rang'): 1,
#  ('to', 'two'): 5,
#  ('daring', 'was'): 1,
#  ('be', 'knew'): 3,
#  ('his', 'evil'): 3,
#  ('point', 'unless'): 1,
#  ('waiter', 'rang'): 1,
#  ('our', 'room'): 1,
#  ('take', 'or'): 1,
#  ('hand', 'taking'): 1,
#  ('cause', 'throwing'): 1,
#  ('like', 'at'): 1,
#  ('own', 'you'): 5,
#  ('conscious', 'seemed'): 2,
#  ('short', 'reentering'): 1,
#  ('money', 'fiveandtwenty'): 1,
#  ('no', 'took'): 3,
#  ('temple', 'things'): 1,
#  ('me', 'taught'): 2,
#  ('vanished', 'set'): 1,
#  ('wear', 'i'): 1,
#  ('process', 'cannot'): 1,
#  ('mouth', 'of'): 1,
#  ('common', 'being'): 1,
#  ('and', 'declined'): 1,
#  ('to', 'better'): 3,
#  ('coming', 'mixing'): 1,
#  ('now', 'glanced'): 1,
#  ('sever', 'being'): 1,
#  ('him', 'tipped'): 1,
#  ('chapter', 'xxxii'): 1,
#  ('nighttwo', 'i'): 1,
#  ('approached', 'i'): 1,
#  ('boy', 'xlii'): 1,
#  ('shining', 'who'): 1,
#  ('door', 'painted'): 1,
#  ('offer', 'accepted'): 1,
#  ('any', 'we'): 3,
#  ('undutifulaltogether', 'the'): 1,
#  ('stop', 'reentering'): 1,
#  ('business', 'late'): 1,
#  ('in', 'written'): 1,
#  ('back', 'changed'): 2,
#  ('much', 'being'): 2,
#  ('jolly', 'they'): 1,
#  ('part', 'for'): 3,
#  ('if', 'from'): 1,
#  ('reading', 'had'): 1,
#  ('disappointment', 'did'): 1,
#  ('brave', 'seemed'): 1,
#  ('ago', 'comfort'): 1,
#  ('sal', 'is'): 1,
#  ('involved', 'before'): 1,
#  ('greasy', 'ate'): 1,
#  ('got', 'with'): 2,
#  ('joe', 'dont'): 4,
#  ('fastcooling', 'the'): 1,
#  ('reputed', 'should'): 1,
#  ('down', 'followed'): 1,
#  ('change', 'change'): 4,
#  ('might', 'developed'): 1,
#  ('pick', 'us'): 1,
#  ('nevertheless', 'appeared'): 1,
#  ('could', 'sorts'): 1,
#  ('i', 'thing'): 4,
#  ('tunnel', 'the'): 1,
#  ('called', 'miss'): 1,
#  ('middle', 'piece'): 1,
#  ('gentleman', 'i'): 5,
#  ('which', 'piece'): 2,
#  ('itknow', 'joseph'): 1,
#  ('animosity', 'bill'): 1,
#  ('much', 'made'): 1,
#  ('of', 'neighborhood'): 3,
#  ('the', 'tide'): 2,
#  ('held', 'held'): 13,
#  ('wind', 'had'): 1,
#  ('on', 'turnpike'): 1,
#  ('and', 'pretty'): 1,
#  ('to', 'might'): 7,
#  ('possession', 'though'): 1,
#  ('their', 'gave'): 2,
#  ('path', 'the'): 2,
#  ('casks', 'matters'): 1,
#  ('same', 'the'): 13,
#  ('miss', 'am'): 8,
#  ('chap', 'cry'): 1,
#  ('do', 'both'): 1,
#  ('proffered', 'again'): 1,
#  ('brown', 'havisham'): 1,
#  ('softened', 'dipped'): 1,
#  ('nearly', 'he'): 1,
#  ('which', 'him'): 1,
#  ('showed', 'sable'): 1,
#  ('havisham', 'those'): 2,
#  ('dearest', 'is'): 1,
#  ('ten', 'thank'): 1,
#  ('conveniently', 'were'): 1,
#  ('memory', 'i'): 1,
#  ('full', 'at'): 1,
#  ('wet', 'are'): 1,
#  ('first', 'within'): 1,
#  ('this', 'part'): 1,
#  ('them', 'that'): 5,
#  ('desert', 'resolution'): 1,
#  ('said', 'united'): 1,
#  ('finger', 'holding'): 1,
#  ('for', 'opportunity'): 1,
#  ('quite', 'began'): 1,
#  ('know', 'added'): 1,
#  ('at', 'always'): 1,
#  ('now', 'forbidden'): 1,
#  ('glad', 'glad'): 1,
#  ('gate', 'started'): 1,
#  ('nervous', 'other'): 1,
#  ('one', 'four'): 1,
#  ('distracted', 'would'): 1,
#  ('bentley', 'finches'): 1,
#  ('couldthough', 'begging'): 1,
#  ('small', 'rented'): 1,
#  ('up', 'lighted'): 1,
#  ('dark', 'would'): 1,
#  ('yard', 'stood'): 1,
#  ('minding', 'verily'): 1,
#  ('try', 'in'): 2,
#  ('everybodys', 'taking'): 1,
#  ('girls', 'who'): 1,
#  ('come', 'boy'): 1,
#  ('rubbing', 'have'): 1,
#  ('son', 'have'): 1,
#  ('sound', 'put'): 1,
#  ('shortly', 'i'): 1,
#  ('love', 'should'): 1,
#  ('or', 'barley'): 1,
#  ('drummle', 'are'): 1,
#  ('rather', 'ought'): 1,
#  ('cross', 'we'): 1,
#  ('endurance', 'have'): 1,
#  ('my', 'ii'): 1,
#  ('times', 'by'): 1,
#  ('doubt', 'when'): 1,
#  ('curse', 'this'): 1,
#  ('combination', 'was'): 1,
#  ('iron', 'was'): 3,
#  ('office', 'the'): 4,
#  ('quitted', 'a'): 1,
#  ('gentlemanly', 'were'): 1,
#  ('casket', 'a'): 1,
#  ('river', 'chambers'): 1,
#  ('returned', 'dear'): 2,
#  ('swum', 'id'): 1,
#  ('pulling', 'was'): 1,
#  ('point', 'must'): 1,
#  ('breast', 'lookee'): 1,
#  ('that', 'by'): 5,
#  ('jaggerss', 'part'): 1,
#  ('classes', 'ageds'): 1,
#  ('him', 'brought'): 2,
#  ('muttonchops', 'muttonchops'): 1,
#  ('myself', 'reasoned'): 1,
#  ('tone', 'this'): 2,
#  ('circumstances', 'last'): 1,
#  ('up', 'only'): 2,
#  ('universal', 'five'): 1,
#  ('in', 'believe'): 2,
#  ('on', 'again'): 1,
#  ('the', 'opposed'): 1,
#  ('yield', 'other'): 1,
#  ('biddy', 'however'): 1,
#  ('door', 'from'): 1,
#  ('unreason', 'all'): 1,
#  ('single', 'looked'): 1,
#  ('or', 'l'): 1,
#  ('this', 'thing'): 1,
#  ('wholly', 'you'): 1,
#  ('terms', 'concluded'): 1,
#  ('like', 'house'): 1,
#  ('leave', 'never'): 1,
#  ('cut', 'well'): 1,
#  ('your', 'fixing'): 1,
#  ('worldly', 'the'): 1,
#  ('low', 'we'): 2,
#  ('rampage', 'lull'): 2,
#  ('six', 'now'): 1,
#  ('resounded', 'said'): 1,
#  ('comfortable', 'boy'): 1,
#  ('employ', 'must'): 1,
#  ('game', 'liked'): 1,
#  ('admire', 'may'): 1,
#  ('guardians', 'had'): 1,
#  ('among', 'was'): 4,
#  ('and', 'may'): 15,
#  ('miss', 'xlix'): 1,
#  ('biddy', 'have'): 1,
#  ('light', 'what'): 1,
#  ('they', 'awakened'): 1,
#  ('thoroughly', 'enjoyed'): 1,
#  ('dreadful', 'cannot'): 1,
#  ('condition', 'will'): 1,
#  ('wholesomely', 'began'): 1,
#  ('up', 'dismally'): 1,
#  ('blazing', 'i'): 1,
#  ('near', 'allotted'): 1,
#  ('premises', 'said'): 1,
#  ('find', 'i'): 6,
#  ('same', 'lap'): 1,
#  ('experience', 'book'): 1,
#  ('caught', 'except'): 1,
#  ('their', 'nooks'): 2,
#  ('want', 'rested'): 1,
#  ('and', 'fearing'): 4,
#  ('nasty', 'to'): 1,
#  ('that', 'above'): 2,
#  ('were', 'wotsumeer'): 1,
#  ('being', 'were'): 2,
#  ('left', 'grinding'): 1,
#  ('her', 'clapped'): 1,
#  ('to', 'certainly'): 1,
#  ('that', 'wemmick'): 1,
#  ('reappeared', 'consumed'): 1,
#  ('deny', 'dont'): 2,
#  ('night', 'inferred'): 1,
#  ('people', 'a'): 1,
#  ('drink', 'i'): 2,
#  ('thinking', 'my'): 2,
#  ('hat', 'i'): 1,
#  ('go', 'and'): 5,
#  ('black', 'also'): 1,
#  ('not', 'guileless'): 1,
#  ('hold', 'opposed'): 1,
#  ('familiarity', 'the'): 1,
#  ('dinnerhour', 'time'): 1,
#  ('although', 'went'): 1,
#  ('said', 'at'): 5,
#  ('xxxiii', 'xxxiii'): 1,
#  ('proof', 'teaboard'): 1,
#  ('heard', 'only'): 1,
#  ('joe', 'thought'): 3,
#  ('the', 'among'): 13,
#  ('wemmick', 'own'): 1,
#  ('written', 'written'): 2,
#  ('sometimes', 'was'): 1,
#  ('jaggers', 'put'): 2,
#  ('thank', 'you'): 8,
#  ('as', 'havishams'): 1,
#  ('cannon', 'had'): 1,
#  ('distinctness', 'united'): 1,
#  ('wordsthat', 'is'): 1,
#  ('one', 'skiffins'): 1,
#  ('elevation', 'i'): 1,
#  ('minutes', 'were'): 1,
#  ('saw', 'saw'): 28,
#  ('choking', 'and'): 1,
#  ('life', 'in'): 2,
#  ('kept', 'have'): 1,
#  ('sir', 'sum'): 1,
#  ('drummle', 'you'): 1,
#  ('my', 'swindling'): 3,
#  ('rotterdam', 'the'): 1,
#  ('board', 'the'): 1,
#  ('for', 'appointed'): 1,
#  ('joes', 'my'): 1,
#  ('broken', 'among'): 1,
#  ('floorcloth', 'avenging'): 1,
#  ('hands', 'hands'): 1,
#  ('now', 'addition'): 1,
#  ('five', 'times'): 3,
#  ('themselves', 'we'): 1,
#  ('of', 'making'): 1,
#  ('furniture', 'saw'): 1,
#  ('i', 'startop'): 1,
#  ('sure', 'am'): 9,
#  ('place', 'said'): 1,
#  ('far', 'were'): 1,
#  ('of', 'gradually'): 2,
#  ('occasion', 'tried'): 1,
#  ('word', 'leaving'): 1,
#  ('of', 'marshes'): 1,
#  ('dark', 'was'): 8,
#  ('rank', 'the'): 2,
#  ('to', 'mother'): 1,
#  ('disadvantage', 'dread'): 1,
#  ('the', 'softly'): 3,
#  ('loitering', 'was'): 1,
#  ('however', 'it'): 2,
#  ('rose', 'now'): 1,
#  ('forgetting', 'falling'): 1,
#  ('difficulty', 'unexpected'): 1,
#  ('firing', 'now'): 1,
#  ('words', 'were'): 3,
#  ('his', 'recollecting'): 2,
#  ('gloss', 'taking'): 1,
#  ('gush', 'and'): 1,
#  ('him', 'worst'): 1,
#  ('months', 'or'): 1,
#  ('discovered', 'the'): 1,
#  ('want', 'tell'): 2,
#  ('so', 'convinced'): 1,
#  ('congelation', 'might'): 1,
#  ('all', 'suffered'): 1,
#  ('that', 'place'): 1,
#  ('rotted', 'was'): 1,
#  ('inflammatory', 'i'): 1,
#  ('will', 'goodness'): 1,
#  ('the', 'knows'): 3,
#  ('recommended', 'i'): 1,
#  ('once', 'glancing'): 1,
#  ('impressive', 'we'): 1,
#  ('shed', 'my'): 4,
#  ('eyes', 'thought'): 1,
#  ('for', 'certain'): 1,
#  ('cooling', 'was'): 1,
#  ('to', 'hue'): 2,
#  ('not', 'but'): 7,
#  ('jewels', 'the'): 1,
#  ('no', 'must'): 1,
#  ('he', 'immediately'): 1,
#  ('kitchen', 'made'): 2,
#  ('highest', 'arm'): 1,
#  ('lively', 'herbert'): 1,
#  ('nor', 'stand'): 1,
#  ('fire', 'thanked'): 1,
#  ('nature', 'am'): 1,
#  ('lying', 'lying'): 1,
#  ('take', 'him'): 4,
#  ('lifenamely', 'as'): 1,
#  ('after', 'received'): 1,
#  ('such', 'heart'): 1,
#  ('as', 'these'): 3,
#  ('for', 'start'): 1,
#  ('agonizing', 'was'): 1,
#  ('gargery', 'you'): 1,
#  ('of', 'wiped'): 1,
#  ('day', 'my'): 1,
#  ('young', 'all'): 1,
#  ('although', 'although'): 2,
#  ('from', 'awakened'): 1,
#  ('gave', 'took'): 2,
#  ('master', 'wish'): 1,
#  ('wear', 'would'): 1,
#  ('fairly', 'looked'): 1,
#  ('aim', 'he'): 1,
#  ('quiet', 'kept'): 1,
#  ('done', 'unless'): 1,
#  ('and', 'watch'): 2,
#  ('speak', 'gentleman'): 1,
#  ('your', 'when'): 5,
#  ('tricks', 'let'): 1,
#  ('performance', 'i'): 1,
#  ('and', 'well'): 1,
#  ('fingers', 'when'): 1,
#  ('after', 'man'): 1,
#  ('or', 'suppose'): 1,
#  ('believe', 'for'): 1,
#  ('disappointed', 'we'): 1,
#  ('actively', 'sister'): 1,
#  ('reflect', 'a'): 1,
#  ('kinds', 'above'): 1,
#  ('said', 'showed'): 1,
#  ('lighting', 'i'): 2,
#  ('having', 'miserable'): 1,
#  ('convicts', 'boat'): 1,
#  ('wine', 'is'): 1,
#  ('and', 'theyre'): 1,
#  ('might', 'stopped'): 1,
#  ('she', 'uttered'): 1,
#  ('me', 'waxwork'): 1,
#  ('first', 'said'): 2,
#  ('hour', 'juniors'): 1,
#  ('i', 'soon'): 11,
#  ('staked', 'in'): 1,
#  ('establish', 'informing'): 1,
#  ('did', 'never'): 2,
#  ('discoveries', 'knew'): 1,
#  ('nose', 'certain'): 1,
#  ('there', 'cold'): 1,
#  ('going', 'when'): 2,
#  ('looking', 'divined'): 1,
#  ('longclothes', 'the'): 1,
#  ('decidedly', 'this'): 1,
#  ('kept', 'house'): 1,
#  ('condethenthun', 'youd'): 1,
#  ('inquiries', 'she'): 1,
#  ('having', 'book'): 1,
#  ('inclinations', 'done'): 1,
#  ('proof', 'for'): 1,
#  ('separation', 'cannot'): 1,
#  ('the', 'fact'): 4,
#  ('both', 'for'): 2,
#  ('one', 'get'): 1,
#  ('me', 'owed'): 1,
#  ('as', 'it'): 22,
#  ('wonder', 'earnestness'): 1,
#  ('desire', 'the'): 1,
#  ('well', 'entered'): 1,
#  ('once', 'looked'): 1,
#  ('ground', 'the'): 1,
#  ('dreary', 'was'): 1,
#  ('very', 'appeared'): 2,
#  ('more', 'alone'): 1,
#  ('so', 'for'): 1,
#  ('taken', 'when'): 2,
#  ('wall', 'xliv'): 1,
#  ('round', 'you'): 2,
#  ('knowd', 'orlick'): 1,
#  ('horse', 'that'): 1,
#  ('the', 'wintry'): 2,
#  ('the', 'lights'): 4,
#  ('her', 'tells'): 1,
#  ('crossed', 'first'): 1,
#  ('groundworse', 'go'): 1,
#  ('keep', 'pledged'): 1,
#  ('have', 'cannot'): 1,
#  ('within', 'lighted'): 1,
#  ('hearth', 'an'): 1,
#  ('by', 'aged'): 1,
#  ('pushed', 'say'): 1,
#  ('i', 'informing'): 2,
#  ('final', 'only'): 1,
#  ('say', 'our'): 1,
#  ('are', 'indeed'): 1,
#  ('beat', 'sometimes'): 2,
#  ('with', 'true'): 1,
#  ('quarter', 'had'): 3,
#  ('began', 'joe'): 1,
#  ('landing', 'the'): 1,
#  ('to', 'him'): 6,
#  ('dream', 'that'): 1,
#  ('rooms', 'up'): 1,
#  ('laying', 'said'): 2,
#  ('blacksmiths', 'was'): 1,
#  ('talk', 'and'): 1,
#  ('otherwise', 'but'): 1,
#  ('wish', 'naturally'): 1,
#  ('strangest', 'an'): 1,
#  ('irregular', 'to'): 1,
#  ('rottenness', 'i'): 1,
#  ('mention', 'to'): 2,
#  ('from', 'there'): 2,
#  ('disagreeable', 'was'): 4,
#  ('twisted', 'had'): 1,
#  ('haggard', 'one'): 1,
#  ('he', 'heavilythat'): 1,
#  ('flight', 'led'): 1,
#  ('meanness', 'had'): 1,
#  ('pockethandkerchief', 'i'): 1,
#  ('blue', 'my'): 1,
#  ('images', 'is'): 1,
#  ('come', 'long'): 1,
#  ('then', 'what'): 3,
#  ('of', 'satisfied'): 1,
#  ('pocket', 'brought'): 1,
#  ('attempt', 'i'): 1,
#  ('surroundings', 'could'): 1,
#  ('and', 'though'): 2,
#  ('staircase', 'lighted'): 1,
#  ('well', 'dinner'): 1,
#  ('domestic', 'to'): 1,
#  ('witch', 'her'): 1,
#  ('see', 'mean'): 1,
#  ('boarder', 'yet'): 1,
#  ('belinda', 'is'): 1,
#  ('my', 'myrmidons'): 2,
#  ('chaisecart', 'appropriated'): 1,
#  ('eyes', 'did'): 2,
#  ('jack', 'what'): 1,
#  ('an', 'return'): 1,
#  ('soon', 'if'): 1,
#  ('alongside', 'had'): 1,
#  ('lines', 'marshes'): 2,
#  ('suddenly', 'yielded'): 1,
#  ('out', 'sir'): 1,
#  ('side', 'emptied'): 1,
#  ('favorable', 'opinion'): 1,
#  ('laughed', 'who'): 2,
#  ('look', 'goodnight'): 2,
#  ('pip', 'old'): 3,
#  ('carving', 'laid'): 1,
#  ('the', 'sooner'): 1,
#  ('in', 'heard'): 2,
#  ('before', 'from'): 1,
#  ('papers', 'of'): 1,
#  ('nothing', 'am'): 1,
#  ('there', 'pip'): 2,
#  ('instance', 'they'): 1,
#  ('other', 'confess'): 1,
#  ('had', 'lix'): 2,
#  ('for', 'remained'): 1,
#  ('to', 'ophelia'): 2,
#  ('wood', 'for'): 1,
#  ('while', 'mrs'): 2,
#  ('thats', 'pocket'): 1,
#  ('law', 'cautioned'): 1,
#  ('fulfilment', 'xxxvi'): 1,
#  ('from', 'imaginary'): 1,
#  ('which', 'stole'): 2,
#  ('admirers', 'her'): 1,
#  ('see', 'half'): 1,
#  ('compliments', 'company'): 1,
#  ('thick', 'she'): 1,
#  ('a', 'real'): 2,
#  ('was', 'trial'): 3,
#  ('beyond', 'hung'): 1,
#  ('head', 'felt'): 2,
#  ('sense', 'we'): 1,
#  ('he', 'turned'): 4,
#  ('pockets', 'did'): 1,
#  ('take', 'pocket'): 1,
#  ('posting', 'was'): 1,
#  ('all', 'turned'): 1,
#  ('something', 'something'): 5,
#  ('you', 'bearing'): 1,
#  ('production', 'day'): 1,
#  ('slow', 'ophelia'): 1,
#  ('jaggers', 'defended'): 1,
#  ('cellars', 'to'): 1,
#  ('over', 'continued'): 1,
#  ('will', 'stronger'): 1,
#  ('within', 'that'): 1,
#  ('steam', 'with'): 1,
#  ('retorted', 'retorted'): 3,
#  ('walking', 'stock'): 1,
#  ('what', 'appeared'): 1,
#  ('grateful', 'you'): 1,
#  ('wood', 'says'): 1,
#  ('both', 'yielded'): 1,
#  ('fire', 'alighting'): 1,
#  ('no', 'hant'): 1,
#  ('make', 'asked'): 2,
#  ('didnt', 'you'): 2,
#  ('told', 'as'): 3,
#  ('to', 'xxviii'): 1,
#  ('held', 'sheep'): 1,
#  ('untoward', 'reflected'): 1,
#  ('fitted', 'this'): 1,
#  ('also', 'the'): 2,
#  ('with', 'not'): 3,
#  ('hat', 'really'): 1,
#  ('coming', 'told'): 1,
#  ('serious', 'last'): 1,
#  ('are', 'have'): 4,
#  ('roll', 'taking'): 1,
#  ('let', 'never'): 1,
#  ('was', 'painted'): 2,
#  ('good', 'if'): 1,
#  ('know', 'if'): 2,
#  ('understood', 'havisham'): 1,
#  ('your', 'at'): 4,
#  ('parting', 'me'): 2,
#  ('were', 'maynt'): 1,
#  ('by', 'guardian'): 1,
#  ('kept', 'soon'): 1,
#  ('clear', 'pretended'): 1,
#  ('safety', 'xl'): 1,
#  ('he', 'at'): 4,
#  ('had', 'air'): 2,
#  ('was', 'old'): 3,
#  ('awfully', 'eyes'): 1,
#  ('remaining', 'chair'): 2,
#  ('not', 'now'): 1,
#  ('up', 'iv'): 1,
#  ('town', 'finches'): 1,
#  ('some', 'havisham'): 1,
#  ('unusual', 'fouroared'): 1,
#  ('was', 'blue'): 2,
#  ('little', 'dont'): 2,
#  ('part', 'can'): 1,
#  ('other', 'i'): 14,
#  ('metropolis', 'xx'): 1,
#  ('us', 'strange'): 1,
#  ('dressingtable', 'xliv'): 1,
#  ('nervously', 'she'): 1,
#  ('better', 'very'): 1,
#  ('fragments', 'was'): 1,
#  ('me', 'seems'): 1,
#  ('that', 'strange'): 2,
#  ('article', 'even'): 1,
#  ('father', 'course'): 1,
#  ('looked', 'entered'): 1,
#  ('following', 'werent'): 1,
#  ('beside', 'five'): 1,
#  ('the', 'wouldnt'): 1,
#  ('beast', 'up'): 1,
#  ('desire', 'aged'): 1,
#  ('floor', 'joe'): 1,
#  ('it', 'revived'): 1,
#  ('red', 'marshes'): 1,
#  ('might', 'former'): 1,
#  ('away', 'miss'): 1,
#  ('all', 'thought'): 2,
#  ('violent', 'had'): 2,
#  ('took', 'again'): 1,
#  ('these', 'there'): 3,
#  ('joe', 'recited'): 1,
#  ('one', 'dont'): 1,
#  ('ago', 'was'): 1,
#  ('would', 'rather'): 1,
#  ('over', 'pleasant'): 1,
#  ('house', 'made'): 2,
#  ('pull', 'i'): 1,
#  ('out', 'eyes'): 1,
#  ('a', 'startop'): 2,
#  ('remembrance', 'a'): 1,
#  ('seated', 'was'): 2,
#  ('coach', 'subdued'): 1,
#  ('was', 'informing'): 1,
#  ('penknife', 'even'): 1,
#  ('hand', 'out'): 1,
#  ('a', 'liii'): 1,
#  ('turn', 'gave'): 1,
#  ('he', 'sighing'): 1,
#  ('he', 'it'): 16,
#  ('delicacy', 'felt'): 1,
#  ('capacities', 'a'): 1,
#  ('daylight', 'there'): 3,
#  ('pot', 'pursued'): 2,
#  ('betrayed', 'i'): 2,
#  ('what', 'if'): 3,
#  ('after', 'if'): 1,
#  ('observe', 'you'): 1,
#  ('out', 'tried'): 1,
#  ('by', 'revived'): 1,
#  ('steadiest', 'can'): 1,
#  ('innocence', 'had'): 1,
#  ('this', 'for'): 2,
#  ('how', 'long'): 5,
#  ('merely', 'ever'): 1,
#  ('regarding', 'that'): 1,
#  ('unto', 'mind'): 1,
#  ('same', 'he'): 4,
#  ('bleeding', 'we'): 1,
#  ('general', 'insensibly'): 1,
#  ('dead', 'tightened'): 1,
#  ('several', 'afterwards'): 1,
#  ('round', 'at'): 1,
#  ('his', 'cherished'): 1,
#  ('dear', 'blessed'): 1,
#  ('cannot', 'it'): 1,
#  ('shipping', 'suppose'): 1,
#  ('great', 'walked'): 1,
#  ('meanwhile', 'mr'): 1,
#  ('every', 'thought'): 1,
#  ('while', 'made'): 2,
#  ('all', 'true'): 2,
#  ('present', 'true'): 2,
#  ('he', 'last'): 6,
#  ('be', 'drive'): 1,
#  ('only', 'like'): 1,
#  ('necessity', 'should'): 1,
#  ('face', 'yet'): 1,
#  ('fed', 'felons'): 1,
#  ('as', 'finished'): 1,
#  ('week', 'this'): 1,
#  ('alleviated', 'depression'): 1,
#  ...}
